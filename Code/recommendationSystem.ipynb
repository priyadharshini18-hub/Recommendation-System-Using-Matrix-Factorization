# %%
import pandas as pd
import json

# %%
def parse(path):
  g = gzip.open(path, 'r')
  for l in g:
    yield json.loads(l)
    
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('meta_All_Beauty.json.gz')

# %%
df.to_csv('dataset_final.csv')

# %%
ratings_dataset = pd.read_csv('/Users/priya/Desktop/tutorials/ratings_Beauty.csv')
products_dataset = pd.read_csv('/Users/priya/Desktop/tutorials/dataset_final.csv')
# Out:
# /usr/local/Homebrew/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3156: DtypeWarning: Columns (2,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ratings_dataset.head()
# Out:
#            UserId   ProductId  Rating   Timestamp
# 0  A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 1  A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 2  A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 3  A1WMRR494NWEWV  0733001998     4.0  1382572800
# 4  A3IAAVS479H7M7  0737104473     1.0  1274227200

# %%
products_dataset.head()
# Out:
#    Unnamed: 0 category tech1  \
# 0           0       []   NaN
# 1           1       []   NaN
# 2           2       []   NaN
# 3           3       []   NaN
# 4           4       []   NaN
#
#                                          description  fit  \
# 0  ["Loud 'N Clear Personal Sound Amplifier allow...  NaN
# 1  ['No7 Lift & Luminate Triple Action Serum 50ml...  NaN
# 2  ["No7 Stay Perfect Foundation now stays perfec...  NaN
# 3                                                 []  NaN
# 4  ['Lacto Calamine Skin Balance Daily Nourishing...  NaN
#
#                                                title  \
# 0      Loud 'N Clear&trade; Personal Sound Amplifier
# 1  No7 Lift &amp; Luminate Triple Action Serum 50...
# 2    No7 Stay Perfect Foundation Cool Vanilla by No7
# 3  Wella Koleston Perfect Hair Colour 44/44 Mediu...
# 4  Lacto Calamine Skin Balance Oil control 120 ml...
#
#                        also_buy  \
# 0                            []
# 1  ['B01E7LCSL6', 'B008X5RVME']
# ...

# %%
pr = ratings_dataset[['UserId', 'ProductId', 'Rating']]
pdes = products_dataset[['title', 'image', 'asin']]

# %%
pr.head()
# Out:
#            UserId   ProductId  Rating
# 0  A39HTATAQ9V7YF  0205616461     5.0
# 1  A3JM6GV9MNOF9X  0558925278     3.0
# 2  A1Z513UWSAAO0F  0558925278     5.0
# 3  A1WMRR494NWEWV  0733001998     4.0
# 4  A3IAAVS479H7M7  0737104473     1.0

# %%
pdes.head()
# Out:
#                                                title  \
# 0      Loud 'N Clear&trade; Personal Sound Amplifier
# 1  No7 Lift &amp; Luminate Triple Action Serum 50...
# 2    No7 Stay Perfect Foundation Cool Vanilla by No7
# 3  Wella Koleston Perfect Hair Colour 44/44 Mediu...
# 4  Lacto Calamine Skin Balance Oil control 120 ml...
#
#                                                image        asin
# 0                                                 []  6546546450
# 1                                                 []  7178680776
# 2                                                 []  7250468162
# 3  ['https://images-na.ssl-images-amazon.com/imag...  7367905066
# 4  ['https://images-na.ssl-images-amazon.com/imag...  7414204790

# %%
full = pd.merge(pr, pdes, left_on= 'ProductId', right_on= 'asin')
full
# Out:
#                UserId   ProductId  Rating  \
# 0       ABVND860D55AJ  7535842801     5.0
# 1      A26TLFFBFPEOKJ  7535842801     4.0
# 2      A2Q8QWVIZM213M  7535842801     3.0
# 3      A3C5DYTUXUCL0S  7535842801     5.0
# 4      A3DNSZT2HIB30J  7535842801     5.0
# ...               ...         ...     ...
# 18022  A2VOO0SJH0CWOL  B00L88S190     5.0
# 18023  A139IQGXUWBPTT  B00L88S190     5.0
# 18024  A1F9B794BGSOD4  B00L88S190     5.0
# 18025  A3RRUMIZ3SJ5PH  B00L88S190     5.0
# 18026   AKR3TTEMPN0T7  B00LJPYR8G     5.0
#
#                                                    title  \
# 0      Mary Kay Satin Hands Hand Cream Travel MINI Si...
# 1      Mary Kay Satin Hands Hand Cream Travel MINI Si...
# 2      Mary Kay Satin Hands Hand Cream Travel MINI Si...
# 3      Mary Kay Satin Hands Hand Cream Travel MINI Si...
# 4      Mary Kay Satin Hands Hand Cream Travel MINI Si...
# ...                                                  ...
# ...
